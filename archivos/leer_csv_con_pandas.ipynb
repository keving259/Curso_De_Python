# %%
import pandas as pd

# %%
archivo = pd.read_csv("datos.csv")

# %%
archivo
# Out:
#     nombre   apellido  edad
# 0    lucas      dalto    97
# 1  roberto  demencial    42
# 2   camila      dalto    24
# 3  nicolas     zosten    27
# 4  maquina  galactica    39
